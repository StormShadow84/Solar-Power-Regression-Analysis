# %%
# Importing the libraries 
import numpy as np 
import matplotlib.pyplot as plt 
import pandas as pd 
import glob 
pd.set_option('display.max_columns',500)
pd.set_option('display.width',1000)

# %%
#pd.read_csv('solar_data_2020_0208_0531_120001pm.csv')
#pd.read_csv('weather_data_2020_0208_0531_1159am.csv')

# %%
solar_data_2020_0208_0531_120001pm_df = pd.read_csv('solar_data_2020_0208_0531_120001pm.csv')

# %%
solar_data_2020_0208_0531_120001pm_df
# Out:
#           date  hour  minute  second  DCMeter-1_V1
# 0   2020-02-08    12       0       1        42.108
# 1   2020-02-09    12       0       1        41.712
# 2   2020-02-10    12       0       1        42.762
# 3   2020-02-11    12       0       1        43.374
# 4   2020-02-12    12       0       1        43.452
# ..         ...   ...     ...     ...           ...
# 64  2020-05-27    12       0       1        33.024
# 65  2020-05-28    12       0       1        33.876
# 66  2020-05-29    12       0       1        42.114
# 67  2020-05-30    12       0       1        33.984
# 68  2020-05-31    12       0       1        37.392
#
# [69 rows x 5 columns]

# %%
weather_data_2020_0208_0531_1159am_df = pd.read_csv('weather_data_2020_0208_0531_1159am.csv')

# %%
weather_data_2020_0208_0531_1159am_df
# Out:
#           date      time             datetime  solarRadiation  uvHigh  winddirAvg  humidityHigh  humidityLow  humidityAvg  qcStatus  tempHigh  tempLow  tempAvg  windspeedHigh  windgustLow  windspeedAvg  dewptHigh  dewptLow  dewptAvg  windchillHigh  windchillAvg  heatindexHigh  heatindexLow  heatindexAvg  pressureMax  pressureMin  pressureTrend  precipRate  precipTotal
# 0   2020-02-08  11:59:00  2020-02-08 11:59:00          655.84     7.0         358            31           30           30         1        63       62       62              5            0             1         32        31        31             63            62             63            62            62        30.16        30.16           0.00        0.00         0.00
# ...

# %%
merged_solar_weather = pd.merge(solar_data_2020_0208_0531_120001pm_df,weather_data_2020_0208_0531_1159am_df, left_on='date', right_on='date', how='inner')

# %%
merged_solar_weather.to_csv('merged_solar_weather.csv', index=False)

# %%
import pandas as pd

import numpy as np

import matplotlib.pyplot as plt

# %matplotlib inline

import seaborn as sns

# %%
df = pd.read_csv('merged_solar_weather.csv')

# %%
df
# Out:
#           date  hour  minute  second  DCMeter-1_V1      time             datetime  solarRadiation  uvHigh  winddirAvg  humidityHigh  humidityLow  humidityAvg  qcStatus  tempHigh  tempLow  tempAvg  windspeedHigh  windgustLow  windspeedAvg  dewptHigh  dewptLow  dewptAvg  windchillHigh  windchillAvg  heatindexHigh  heatindexLow  heatindexAvg  pressureMax  pressureMin  pressureTrend  precipRate  precipTotal
# 0   2020-02-08    12       0       1        42.108  11:59:00  2020-02-08 11:59:00          655.84     7.0         358            31           30           30         1        63       62       62              5            0             1         32        31        31             63            62             63            62            62        30.16        30.16           0.00        0.00         0.00
# ...

# %%
x=df[['solarRadiation','uvHigh','winddirAvg','humidityHigh','humidityLow','humidityAvg','qcStatus','tempHigh','tempLow','tempAvg','windspeedHigh','windgustLow','windspeedAvg','dewptHigh','dewptLow','dewptAvg','windchillHigh','windchillAvg','heatindexHigh','heatindexLow','heatindexAvg','pressureMax','pressureMin','pressureTrend','precipRate','precipTotal']]

# %%
y = df['DCMeter-1_V1']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3)

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(x_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
print(model.coef_)
# Out:
# [ 1.48564030e-02 -1.09374713e+00 -9.35162217e-04  1.50793770e-01
#   1.47491115e+00 -1.80219605e+00 -2.89837335e+00  1.95675940e-01
#  -2.82736048e-01 -7.07062988e+00  1.57741383e-01 -4.64114831e-01
#  -1.13900207e-01  2.38999561e-01 -7.37984660e-01  8.17959310e-01
#   1.95675939e-01  6.21415362e+00 -6.81538392e-01  2.74535892e-01
#   7.39657478e-01 -4.59203075e+01  4.51727674e+01 -3.24023741e-01
#  -3.60351517e+02  1.14149191e+02]

# %%
print(model.intercept_)
# Out:
# 85.36793908282665

# %%
pd.DataFrame(model.coef_, x.columns, columns = ['Coeff'])
# Out:
#                      Coeff
# solarRadiation    0.014856
# uvHigh           -1.093747
# winddirAvg       -0.000935
# humidityHigh      0.150794
# humidityLow       1.474911
# humidityAvg      -1.802196
# qcStatus         -2.898373
# tempHigh          0.195676
# tempLow          -0.282736
# tempAvg          -7.070630
# windspeedHigh     0.157741
# windgustLow      -0.464115
# windspeedAvg     -0.113900
# dewptHigh         0.239000
# dewptLow         -0.737985
# dewptAvg          0.817959
# windchillHigh     0.195676
# windchillAvg      6.214154
# heatindexHigh    -0.681538
# heatindexLow      0.274536
# heatindexAvg      0.739657
# pressureMax     -45.920308
# pressureMin      45.172767
# pressureTrend    -0.324024
# precipRate     -360.351517
# precipTotal     114.149191

# %%
predictions = model.predict(x_test)

# %%
plt.hist(y_test - predictions)
# Out:
# (array([1., 0., 0., 0., 0., 0., 1., 4., 9., 2.]),
#  array([-31.55447725, -27.56579927, -23.57712128, -19.58844329,
#         -15.5997653 , -11.61108731,  -7.62240932,  -3.63373133,
#           0.35494666,   4.34362464,   8.33230263]),
#  <a list of 10 Patch objects>)

# %%
from sklearn import metrics

# %%
metrics.mean_absolute_error(y_test, predictions)
# Out:
# 4.549147823304408

# %%
metrics.mean_squared_error(y_test, predictions)
# Out:
# 70.05891719729934

# %%
np.sqrt(metrics.mean_squared_error(y_test, predictions))
# Out:
# 8.370120500763376

# %%
#test the performance of training model via MAE, MSE and RMSE
pred_train=model.predict(x_train)
metrics.mean_absolute_error(y_train, pred_train)
# Out:
# 0.5178442462527321

# %%
metrics.mean_squared_error(y_train, pred_train)
# Out:
# 0.43812222272673057

# %%
#Scatter Plot

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('merged_solar_weather.csv')

cols = ['DCMeter-1_V1','solarRadiation','uvHigh','pressureTrend','precipRate',]
sns.pairplot(df[cols], height=2.5)

plt.tight_layout()
plt.show()

# %%
# Importing the libraries 
import numpy as np 
import matplotlib.pyplot as plt 
import pandas as pd
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from pylab import*

# %%
#Random Forest

# %%
import pandas as pd

import numpy as np

import matplotlib.pyplot as plt

# %matplotlib inline

import seaborn as sns

from sklearn import metrics

# %%
df = pd.read_csv('merged_solar_weather.csv')

# %%
x=df[['solarRadiation','uvHigh','winddirAvg','humidityHigh','humidityLow','humidityAvg','qcStatus','tempHigh','tempLow','tempAvg','windspeedHigh','windgustLow','windspeedAvg','dewptHigh','dewptLow','dewptAvg','windchillHigh','windchillAvg','heatindexHigh','heatindexLow','heatindexAvg','pressureMax','pressureMin','pressureTrend','precipRate','precipTotal']]

# %%
y = df['DCMeter-1_V1']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3)

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(x_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
#test the performance of training model via MAE, MSE and RMSE
pred_train=model.predict(x_train)
metrics.mean_absolute_error(y_train, pred_train)
# Out:
# 0.652936540602417

# %%
metrics.mean_squared_error(y_train, pred_train)
# Out:
# 0.7597144056945571

# %%
from sklearn.metrics import r2_score
r2_train = metrics.r2_score (y_train, y_train)
r2_test = metrics.r2_score (y_test, y_test )
print('R^2 train: %.3f, test:%.3f' % (r2_train, r2_test))
# Out:
# R^2 train: 1.000, test:1.000

# %%
from sklearn.ensemble import RandomForestRegressor
x = df[['solarRadiation','uvHigh','winddirAvg','humidityHigh','humidityLow','humidityAvg','qcStatus','tempHigh','tempLow','tempAvg','windspeedHigh','windgustLow','windspeedAvg','dewptHigh','dewptLow','dewptAvg','windchillHigh','windchillAvg','heatindexHigh','heatindexLow','heatindexAvg','pressureMax','pressureMin','pressureTrend','precipRate','precipTotal']].values
y = df[['DCMeter-1_V1']].values
forest = RandomForestRegressor(n_estimators=1000, criterion='mse', random_state=1, n_jobs=10)
forest.fit(X, y)
y_pred = forest.predict(X)
error = metrics.mean_squared_error(y, y_pred)
r2 = metrics.r2_score (y, y_pred)
print('MSE: %.3f, R2:%.3f' % (error, r2))
# Out:
# C:\Users\storm\anaconda3\lib\site-packages\ipykernel_launcher.py:5: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   """
# MSE: 0.659, R2:0.928
